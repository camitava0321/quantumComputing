# %%
# qiskit_superposition
#Various state can be expressed at the same time by creating superposition.
#In terms of n bits binary number, we can easily make n states by operating Hadamard to all the qubits.  

#What if we want to make n-1 states by n qubits?
#That is no so simple, so my goal is to make an algorithm which enables us to make any kinds of superposition.

import numpy as np
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit import IBMQ, execute, Aer
from qiskit.tools.visualization import plot_histogram
import math

# %%
#2 qubits superposition
q = QuantumRegister(2, 'q')  #00, 01, 11
c = ClassicalRegister(2, 'c')
qc = QuantumCircuit(q, c)

theta = 2 * np.arccos(1 / np.sqrt(3))

qc.ry(theta, q[0])
qc.ch(q[0], q[1])

qc.measure(q[0:2], c[0:2])

r = execute(qc, Aer.get_backend('qasm_simulator')).result()
rc = r.get_counts()
print(rc)
plot_histogram(rc)
# Out:
# {'01': 341, '00': 343, '11': 340}

# %%
q = QuantumRegister(2, 'q')  #01, 10, 11
c = ClassicalRegister(2, 'c')
qc = QuantumCircuit(q, c)

theta = 2 * np.arccos(1 / np.sqrt(3))

qc.ry(theta, q[0])
qc.ch(q[0], q[1])
qc.x(q[1])

qc.measure(q[0:2], c[0:2])

r = execute(qc, Aer.get_backend('qasm_simulator')).result()
rc = r.get_counts()
print(rc)
plot_histogram(rc)
# Out:
# {'01': 367, '10': 326, '11': 331}

# %%
q = QuantumRegister(2, 'q')  #00, 10, 11
c = ClassicalRegister(2, 'c')
qc = QuantumCircuit(q, c)

theta = 2 * np.arccos(1 / np.sqrt(3))

qc.ry(theta, q[1])
qc.ch(q[1], q[0])
qc.measure(q[0:2], c[0:2])

r = execute(qc, Aer.get_backend('qasm_simulator')).result()
rc = r.get_counts()
print(rc)
plot_histogram(rc)
# Out:
# {'00': 357, '10': 327, '11': 340}

# %%
q = QuantumRegister(2, 'q')  #00, 01, 10
c = ClassicalRegister(2, 'c')
qc = QuantumCircuit(q, c)

theta = 2 * np.arccos(1 / np.sqrt(3))

qc.ry(theta, q[1])
qc.ch(q[1], q[0])
qc.x(q[1])

qc.measure(q[0:2], c[0:2])

r = execute(qc, Aer.get_backend('qasm_simulator')).result()
rc = r.get_counts()
print(rc)
plot_histogram(rc)
# Out:
# {'01': 358, '00': 349, '10': 317}
